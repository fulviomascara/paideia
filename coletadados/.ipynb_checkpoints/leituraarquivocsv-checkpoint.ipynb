# %%
# importar bibliotecas necessárias
import pandas as pd
import numpy as np # biblioteca de algebra linear
import matplotlib.pyplot as plt # biblioteca para graficos
# %matplotlib inline

# %%
# ?pd.read_csv
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]],
#     sep=',',
#     delimiter=None,
#     header='infer',
#     names=None,
#     index_col=None,
#     usecols=None,
#     squeeze=False,
#     prefix=None,
#     mangle_dupe_cols=True,
#     dtype=None,
#     engine=None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace=False,
#     skiprows=None,
#     skipfooter=0,
#     nrows=None,
#     na_values=None,
#     keep_default_na=True,
#     na_filter=True,
#     verbose=False,
#     skip_blank_lines=True,
#     parse_dates=False,
#     infer_datetime_format=False,
#     keep_date_col=False,
#     date_parser=None,
#     dayfirst=False,
#     cache_dates=True,
#     iterator=False,
#     chunksize=None,
#     compression='infer',
#     thousands=None,
#     decimal=b'.',
#     lineterminator=None,
#     quotechar='"',
#     quoting=0,
#     doublequote=True,
#     escapechar=None,
# ...

# %%
# importar arquivo CSV
df_anp = pd.read_csv("infopreco.csv", sep = ';', decimal = ',', encoding = 'cp1252')

# %%
df_anp
# Out:
#                CNPJ                                               NOME  \
# 0       62780000102                                  AUTO POSTO PARATI
# 1       62780000102                                  AUTO POSTO PARATI
# 2       62780000102                                  AUTO POSTO PARATI
# 3       62780000102                                  AUTO POSTO PARATI
# 4      300357000195                    POSTO E TRANSPORTADORA PEGORARO
# ..              ...                                                ...
# 858  93777456000143                                  POSTO PAMPEANO II
# 859  93777456000143                                  POSTO PAMPEANO II
# 860  98749864000105  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...
# 861  98749864000105  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...
# 862  98749864000105  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...
#
#                            ENDEREÇO COMPLEMENTO        BAIRRO  \
# ...

# %%
# visualiza inicio do dataframe - 5 primeiras linhas
df_anp.head()
# Out:
#            CNPJ                             NOME                    ENDEREÇO  \
# 0   62780000102                AUTO POSTO PARATI  AVENIDA FILINTO MULLER,645
# 1   62780000102                AUTO POSTO PARATI  AVENIDA FILINTO MULLER,645
# 2   62780000102                AUTO POSTO PARATI  AVENIDA FILINTO MULLER,645
# 3   62780000102                AUTO POSTO PARATI  AVENIDA FILINTO MULLER,645
# 4  300357000195  POSTO E TRANSPORTADORA PEGORARO          RODOVIA BR 163,S/N
#
#   COMPLEMENTO      BAIRRO    MUNICÍPIO  UF           PRODUTO  VALOR VENDA  \
# 0         NaN      CENTRO  TRES LAGOAS  MS  Gasolina C Comum        4.436
# 1         NaN      CENTRO  TRES LAGOAS  MS            Etanol        3.482
# 2         NaN      CENTRO  TRES LAGOAS  MS       Diesel S500        3.644
# 3         NaN      CENTRO  TRES LAGOAS  MS        Diesel S10        3.734
# 4      KM 786  ZONA RURAL        COXIM  MS  Gasolina C Comum        4.349
#
#       DATA CADASTRO
# 0  28/06/2018 17:49
# ...

# %%
# visualiza final do dataframe - 5 últimas linhas
df_anp.tail()
# Out:
#                CNPJ                                               NOME  \
# 858  93777456000143                                  POSTO PAMPEANO II
# 859  93777456000143                                  POSTO PAMPEANO II
# 860  98749864000105  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...
# 861  98749864000105  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...
# 862  98749864000105  FIGUEIRA CENTRO COMERCIO E DERIVADOS DE COMBUS...
#
#                            ENDEREÇO COMPLEMENTO        BAIRRO  \
# 858  AVENIDA PRESIDENTE KENNEDY,185         NaN  VILA BATISTA
# 859  AVENIDA PRESIDENTE KENNEDY,185         NaN  VILA BATISTA
# 860        RUA BENTO GONCALVES,1295         NaN        CENTRO
# 861        RUA BENTO GONCALVES,1295         NaN        CENTRO
# 862        RUA BENTO GONCALVES,1295         NaN        CENTRO
#
#            MUNICÍPIO  UF           PRODUTO  VALOR VENDA     DATA CADASTRO
# 858  CACAPAVA DO SUL  RS       Diesel S500        3.327  29/06/2018 12:01
# ...

# %%
# visualizar estrutura do Dataframe
df_anp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 10 columns):
# CNPJ             863 non-null int64
# NOME             863 non-null object
# ENDEREÇO         863 non-null object
# COMPLEMENTO      258 non-null object
# BAIRRO           852 non-null object
# MUNICÍPIO        863 non-null object
# UF               863 non-null object
# PRODUTO          863 non-null object
# VALOR VENDA      863 non-null float64
# DATA CADASTRO    863 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 67.5+ KB

# %%
# tirar a media do valor de venda
df_anp['VALOR VENDA'].mean()
# Out:
# 9.643046349942063

# %%
# apresentar medidas estatisticas
df_anp.describe()
# Out:
#                CNPJ  VALOR VENDA
# count  8.630000e+02   863.000000
# mean   1.684245e+13     9.643046
# std    1.880234e+13    49.695239
# min    6.278000e+10     0.001000
# 25%    4.687124e+12     3.490000
# 50%    1.100064e+13     3.779000
# 75%    2.138746e+13     4.249000
# max    9.874986e+13   550.000000

# %%
# apresentar valores unicos de uma coluna
df_anp['PRODUTO'].unique()
# Out:
# array(['Gasolina C Comum', 'Etanol', 'Diesel S500', 'Diesel S10', 'GNV'],
#       dtype=object)

# %%
# tirar a média do valor de venda do Etanol
df_anp[df_anp['PRODUTO'] == 'Etanol']['VALOR VENDA'].mean()
# Out:
# 7.346508108108108

# %%
# descrever apenas os dados do produto Etanol
df_anp[df_anp['PRODUTO'] == 'Etanol'].describe()
# Out:
#                CNPJ  VALOR VENDA
# count  1.850000e+02   185.000000
# mean   1.706589e+13     3.338346
# std    1.811553e+13     0.534167
# min    6.278000e+10     1.000000
# 25%    4.785105e+12     2.950000
# 50%    1.130760e+13     3.299000
# 75%    2.279413e+13     3.690000
# max    9.377746e+13     4.690000

# %%
# visualizar gráfico de distribuição dos valores de venda do Etanol
df_anp[df_anp['PRODUTO'] == 'Etanol']['VALOR VENDA'].hist()

# %%
# visualizar valores acima de 100,00 no preço do Etanol
df_anp[(df_anp['PRODUTO'] == 'Etanol') & (df_anp['VALOR VENDA'] > 100)]
# Out:
#               CNPJ                            NOME  \
# 206  4624593000118  C JUSTINIANO ROCHA & CIA LTDA.
#
#                           ENDEREÇO COMPLEMENTO  BAIRRO MUNICÍPIO  UF PRODUTO  \
# 206  AVENIDA LUCIO PEREIRA LUZ,790         NaN  CENTRO   LUCIARA  MT  Etanol
#
#      VALOR VENDA     DATA CADASTRO
# 206        360.0  14/06/2019 10:28

# %%
# visualizar preços do posto nova pirai
df_anp[(df_anp['NOME'] == 'POSTO NOVA PIRAI')]
# Out:
#               CNPJ              NOME               ENDEREÇO COMPLEMENTO  \
# 197  4528732000371  POSTO NOVA PIRAI  RUA XV DE NOVEMBRO,36      GALPAO
# 198  4528732000371  POSTO NOVA PIRAI  RUA XV DE NOVEMBRO,36      GALPAO
# 199  4528732000371  POSTO NOVA PIRAI  RUA XV DE NOVEMBRO,36      GALPAO
# 200  4528732000371  POSTO NOVA PIRAI  RUA XV DE NOVEMBRO,36      GALPAO
# 201  4528732000371  POSTO NOVA PIRAI  RUA XV DE NOVEMBRO,36      GALPAO
#
#      BAIRRO MUNICÍPIO  UF           PRODUTO  VALOR VENDA     DATA CADASTRO
# 197  CENTRO     PIRAI  RJ  Gasolina C Comum         4.99  16/08/2019 11:39
# 198  CENTRO     PIRAI  RJ            Etanol         3.89  16/08/2019 11:39
# 199  CENTRO     PIRAI  RJ               GNV         3.49  16/08/2019 11:39
# 200  CENTRO     PIRAI  RJ       Diesel S500         3.49  16/08/2019 11:39
# 201  CENTRO     PIRAI  RJ        Diesel S10         3.59  16/08/2019 11:39

# %%
# ajustar valores do posto nova pirai, dividindo o valor de venda por 100
df_anp.loc[df_anp['NOME'] == 'POSTO NOVA PIRAI', 'VALOR VENDA'] = df_anp['VALOR VENDA'] / 100

# %%
# visualizar preços do posto C JUSTINIANO
df_anp[(df_anp['NOME'] == 'C JUSTINIANO ROCHA & CIA LTDA.')]
# Out:
#               CNPJ                            NOME  \
# 205  4624593000118  C JUSTINIANO ROCHA & CIA LTDA.
# 206  4624593000118  C JUSTINIANO ROCHA & CIA LTDA.
# 207  4624593000118  C JUSTINIANO ROCHA & CIA LTDA.
# 208  4624593000118  C JUSTINIANO ROCHA & CIA LTDA.
#
#                           ENDEREÇO COMPLEMENTO  BAIRRO MUNICÍPIO  UF  \
# 205  AVENIDA LUCIO PEREIRA LUZ,790         NaN  CENTRO   LUCIARA  MT
# 206  AVENIDA LUCIO PEREIRA LUZ,790         NaN  CENTRO   LUCIARA  MT
# 207  AVENIDA LUCIO PEREIRA LUZ,790         NaN  CENTRO   LUCIARA  MT
# 208  AVENIDA LUCIO PEREIRA LUZ,790         NaN  CENTRO   LUCIARA  MT
#
#               PRODUTO  VALOR VENDA     DATA CADASTRO
# 205  Gasolina C Comum        550.0  14/06/2019 10:28
# 206            Etanol        360.0  14/06/2019 10:28
# 207       Diesel S500        445.0  14/06/2019 10:28
# 208        Diesel S10        455.0  14/06/2019 10:28

# %%
# ajustar valores do posto C JUSTINIANO, dividindo o valor de venda por 100
df_anp.loc[df_anp['NOME'] == 'C JUSTINIANO ROCHA & CIA LTDA.', 'VALOR VENDA'] = df_anp['VALOR VENDA'] / 100

# %%
# descrever apenas os dados do produto Gasolina Comum
df_anp[df_anp['PRODUTO'] == 'Gasolina C Comum'].describe()
# Out:
#                CNPJ  VALOR VENDA
# count  2.530000e+02   253.000000
# mean   1.701082e+13     4.533719
# std    1.868514e+13     0.421728
# min    6.278000e+10     1.000000
# 25%    4.878675e+12     4.299000
# 50%    1.106029e+13     4.569000
# 75%    2.213947e+13     4.799000
# max    9.874986e+13     5.500000

# %%
# visualizar valores acima de 100,00 no preço da Gasolina C Comum
df_anp[(df_anp['PRODUTO'] == 'Gasolina C Comum') & (df_anp['VALOR VENDA'] > 100)]
# Out:
#                CNPJ               NOME                            ENDEREÇO  \
# 422  10750422000138  POSTO PONTO CERTO  AVENIDA GOV. FERNANDO GUILHON,1300
#
#     COMPLEMENTO       BAIRRO              MUNICÍPIO  UF           PRODUTO  \
# 422         NaN  SAO LUIZ II  CONCEICAO DO ARAGUAIA  PA  Gasolina C Comum
#
#      VALOR VENDA     DATA CADASTRO
# 422        505.0  13/05/2019 16:43

# %%
# visualizar preços do posto nova pirai
df_anp[(df_anp['NOME'] == 'POSTO PONTO CERTO')]
# Out:
#                CNPJ               NOME                            ENDEREÇO  \
# 422  10750422000138  POSTO PONTO CERTO  AVENIDA GOV. FERNANDO GUILHON,1300
# 423  10750422000138  POSTO PONTO CERTO  AVENIDA GOV. FERNANDO GUILHON,1300
# 424  10750422000138  POSTO PONTO CERTO  AVENIDA GOV. FERNANDO GUILHON,1300
#
#     COMPLEMENTO       BAIRRO              MUNICÍPIO  UF           PRODUTO  \
# 422         NaN  SAO LUIZ II  CONCEICAO DO ARAGUAIA  PA  Gasolina C Comum
# 423         NaN  SAO LUIZ II  CONCEICAO DO ARAGUAIA  PA       Diesel S500
# 424         NaN  SAO LUIZ II  CONCEICAO DO ARAGUAIA  PA        Diesel S10
#
#      VALOR VENDA     DATA CADASTRO
# 422        505.0  13/05/2019 16:43
# 423        405.0  13/05/2019 16:43
# 424        409.0  13/05/2019 16:43

# %%
# ajustar valores do posto POSTO PONTO CERTO, dividindo o valor de venda por 100
df_anp.loc[df_anp['NOME'] == 'POSTO PONTO CERTO', 'VALOR VENDA'] = df_anp['VALOR VENDA'] / 100

# %%
# visualizar gráfico de distribuição dos valores de venda da Gasolina C Comum
df_anp[df_anp['PRODUTO'] == 'Gasolina C Comum']['VALOR VENDA'].hist()
